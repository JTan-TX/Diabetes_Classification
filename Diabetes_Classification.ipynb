# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data[data['BloodPressure']==0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      115              0              0        0  35.3
# 15             7      100              0              0        0  30.0
# 49             7      105              0              0        0   0.0
# 60             2       84              0              0        0   0.0
# 78             0      131              0              0        0  43.2
# 81             2       74              0              0        0   0.0
# 172            2       87              0             23        0  28.9
# 193           11      135              0              0        0  52.3
# 222            7      119              0              0        0  25.2
# 261            3      141              0              0        0  30.0
# 266            0      138              0              0        0  36.3
# 269            2      146              0              0        0  27.5
# ...

# %%
#fig,ax = plt.subplots(figsize = (10,5))
sns.histplot(data[data['Outcome']==0]['DiabetesPedigreeFunction'],color='green')
sns.histplot(data[data['Outcome']==1]['DiabetesPedigreeFunction'],color='red')
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Count'>

# %%
data[data['DiabetesPedigreeFunction']==0]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
sns.pairplot(data,hue='Outcome')

# %%
corr_matrix = data.corr()
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(corr_matrix, cmap = 'RdYlGn', annot = True)
# Out:
# <AxesSubplot:>

# %%
columns = data.columns
columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
columns[0:8]
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
len_col = len(columns)
num_fig = len_col - 1;

fig, axes = plt.subplots(num_fig, 1, figsize = (10, num_fig * 10))

count = 0
for column in columns[0:len_col-1]:
    
    sns.histplot(x = column, data=data, hue='Outcome', ax = axes[count])
    axes[count].set_xlabel(column)
    count += 1

fig.tight_layout()

# %%
plt.figure(figsize=(20, 15))
plotnumber = 1
 
for feature in data.columns[2:4]:
    ax = plt.subplot(2, 1, plotnumber)
    ax = sns.histplot(x = feature, hue = 'Outcome', data = data, palette=['#432371',"#FAAE7B"])
    plt.setp(ax.get_legend().get_texts(), fontsize='15') 
    plt.xlabel(feature, size = 20)
    plt.title(feature, size = 30)
    plt.xticks(size = 18)
    ax.set_ylabel('')
    plt.yticks(size = 18)
    plotnumber += 1
    plt.tight_layout()
    ;

# %%
data['Outcome'].value_counts().plot(kind='barh',label = '1: Diabetes 0: Non-diabetes')
plt.xlabel('Total patients')
plt.ylabel('Outcome')
plt.legend()

# %%
outcome_map = {
    1: 'Diabetes',
    0: 'Non-diabetes'
}
data['Outcome_label'] = data['Outcome'].map(outcome_map)
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome Outcome_label
# ...

# %%
data['Outcome_label'].value_counts().plot(kind='pie', autopct='%1.2f%%')
plt.legend()

# %%
data['Outcome'].value_counts().plot(kind='pie', autopct='%1.2f%%')
plt.legend()

# %% [markdown]
# ### Model training

# %% [markdown]
# Create X and y

# %%
X = data.drop(['Outcome','Outcome_label'],axis = 1)
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# Scale features and split train and test sets

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
y = data['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=40)

# %%
len(X_train)
# Out:
# 614

# %%
len(X_test)
# Out:
# 154

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Apply Gridsearch to find the best SVM model

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'kernel': ['linear', 'rbf'],
    'C':[1, 10, 20]
    
}
svc = svm.SVC()
clf = GridSearchCV(svc, params, cv = 5, return_train_score = False)
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 10, 20], 'kernel': ['linear', 'rbf']})

# %%
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.007777      0.001161         0.000797        0.000398       1
# 1       0.006183      0.000399         0.001397        0.000489       1
# 2       0.028333      0.002794         0.000997        0.000001      10
# 3       0.008969      0.000631         0.001196        0.000400      10
# 4       0.057255      0.013770         0.000597        0.000487      20
# 5       0.011169      0.000746         0.001197        0.000400      20
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.780488
# 1          rbf      {'C': 1, 'kernel': 'rbf'}           0.813008
# 2       linear  {'C': 10, 'kernel': 'linear'}           0.780488
# 3          rbf     {'C': 10, 'kernel': 'rbf'}           0.780488
# 4       linear  {'C': 20, 'kernel': 'linear'}           0.780488
# 5          rbf     {'C': 20, 'kernel': 'rbf'}           0.739837
#
# ...

# %%
df[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1       linear         0.772011
# 1       1          rbf         0.771998
# 2      10       linear         0.773637
# 3      10          rbf         0.749180
# 4      20       linear         0.775263
# 5      20          rbf         0.721511

# %%
params = {
    'C':[20,50,100]
}

# %%
svc = svm.SVC(kernel = 'linear')
clf = GridSearchCV(svc, params, cv = 5, return_train_score = False)
clf.fit(X_train, y_train)
df = pd.DataFrame(clf.cv_results_)
df[['param_C','mean_test_score']]
# Out:
#   param_C  mean_test_score
# 0      20         0.775263
# 1      50         0.775263
# 2     100         0.773637

# %% [markdown]
# Find the best model among SVM, random forest, and logistic regression

# %%
model_params = {
    'svm':{
        'model':svm.SVC(gamma = 'auto'),
        'param': {
            'kernel':['linear','rbf'],
            'C':[10,20,50]
        }
        
    },
    'random_forest':{
        'model': RandomForestClassifier(),
        'param': {
            'n_estimators': [1,5,10]
        }
        
    },
    'logistic_regression':{
        'model': LogisticRegression(),
        'param': {
            'C': [1,5,10]
        }
        
    }
}

# %%
pd.DataFrame(model_params.items())
# Out:
#                      0                                                  1
# 0                  svm  {'model': SVC(gamma='auto'), 'param': {'kernel...
# 1        random_forest  {'model': RandomForestClassifier(), 'param': {...
# 2  logistic_regression  {'model': LogisticRegression(), 'param': {'C':...

# %%
scores = []
for model,mp in model_params.items():    
    clf = GridSearchCV(mp['model'], mp['param'], cv = 5, return_train_score = False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': model,
        'best_score': clf.best_score_,
        'best_param': clf.best_params_ 
    })
pd.DataFrame(scores)
# Out:
#                  model  best_score                     best_param
# 0                  svm    0.775263  {'C': 20, 'kernel': 'linear'}
# 1        random_forest    0.729735           {'n_estimators': 10}
# 2  logistic_regression    0.770372                       {'C': 1}

# %%
model_params = {
    'random_forest':{
        'model': RandomForestClassifier(),
        'param': {
            'n_estimators': [10,50,100]
        }
        
    },
    'logistic_regression':{
        'model': LogisticRegression(),
        'param': {
            'C': [0.01, 0.1, 1]
        }
        
    }
}

# %%
scores = []
for model,mp in model_params.items():    
    clf = GridSearchCV(mp['model'], mp['param'], cv = 5, return_train_score = False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': model,
        'best_score': clf.best_score_,
        'best_param': clf.best_params_ 
    })
pd.DataFrame(scores)
# Out:
#                  model  best_score            best_param
# 0        random_forest    0.762282  {'n_estimators': 50}
# 1  logistic_regression    0.770372              {'C': 1}

# %%
model = svm.SVC(gamma = 'auto', kernel = 'linear', C = 20)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=20, gamma='auto', kernel='linear')

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82        95
#            1       0.78      0.53      0.63        59
#
#     accuracy                           0.76       154
#    macro avg       0.76      0.72      0.72       154
# weighted avg       0.76      0.76      0.75       154

# %%
confusion_matrix = confusion_matrix(y_test, y_pred)

cm_display = ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %% [markdown]
# ### Decision tree model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83        95
#            1       0.74      0.66      0.70        59
#
#     accuracy                           0.78       154
#    macro avg       0.77      0.76      0.76       154
# weighted avg       0.78      0.78      0.78       154

# %%
confusion_matrix = confusion_matrix(y_test, y_pred)

cm_display = ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-56418fb8a833> in <module>
# ----> 1 confusion_matrix = confusion_matrix(y_test, y_pred)
#       2
#       3 cm_display = ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
#       4
#       5 cm_display.plot()
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# ### Outlier treatment before model training
# 1. remove outlier before traning
# 2. replace outlier by median value before training

# %%
data.columns

# %%
data.boxplot(column = ['Pregnancies'], by='Outcome',grid = True)
plt.tight_layout()

# %%
data.describe()

# %%
data.boxplot(column = ['Pregnancies'],grid = True)
plt.tight_layout()

# %%
x_columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']
x_columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
data_cp = data
for col in x_columns:
    Q1 = np.percentile(data[col], 25, method = 'midpoint')
    Q3 = np.percentile(data[col], 75, method = 'midpoint')
    IQR = Q3 - Q1
    med = np.median(data[col])
    data_cp[data[col]>Q3+1.5*IQR] = med
    data_cp[data[col]<Q1-1.5*IQR] = med

# %%
data_cp
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin      BMI  \
# 0         6.0000  148.0000        72.0000        35.0000    0.0000  33.6000
# 1         1.0000   85.0000        66.0000        29.0000    0.0000  26.6000
# 2         8.0000  183.0000        64.0000         0.0000    0.0000  23.3000
# 3         1.0000   89.0000        66.0000        23.0000   94.0000  28.1000
# 4         0.4335    0.4335         0.4335         0.4335    0.4335   0.4335
# ..           ...       ...            ...            ...       ...      ...
# 763      27.0000   27.0000        27.0000        27.0000   27.0000  27.0000
# 764       2.0000  122.0000        70.0000        27.0000    0.0000  36.8000
# 765       5.0000  121.0000        72.0000        23.0000  112.0000  26.2000
# 766       1.0000  126.0000        60.0000         0.0000    0.0000  30.1000
# 767       1.0000   93.0000        70.0000        31.0000    0.0000  30.4000
#
# ...

# %%
data.boxplot(column = ['Pregnancies'],grid = True)
# Out:
# <AxesSubplot:>

# %%
data_cp.boxplot(column = ['Pregnancies'],grid = True)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin      BMI  \
# 0         6.0000  148.0000        72.0000        35.0000    0.0000  33.6000
# 1         1.0000   85.0000        66.0000        29.0000    0.0000  26.6000
# 2         8.0000  183.0000        64.0000         0.0000    0.0000  23.3000
# 3         1.0000   89.0000        66.0000        23.0000   94.0000  28.1000
# 4         0.4335    0.4335         0.4335         0.4335    0.4335   0.4335
# ..           ...       ...            ...            ...       ...      ...
# 763      27.0000   27.0000        27.0000        27.0000   27.0000  27.0000
# 764       2.0000  122.0000        70.0000        27.0000    0.0000  36.8000
# 765       5.0000  121.0000        72.0000        23.0000  112.0000  26.2000
# 766       1.0000  126.0000        60.0000         0.0000    0.0000  30.1000
# 767       1.0000   93.0000        70.0000        31.0000    0.0000  30.4000
#
# ...
